# %%
a = {}
a.get(("m","n"))
a[("m","n")]=2
a
# Out:
# {('m', 'n'): 2}

# %%
from numpy.random import random
from random import randint
#epsilon greedy strategy the agent visit new states with epsilon probability
EPSILON = 0.1
#number of bandits
BANDITS = 3
#number of iterations.
EPISODES = 10000

# %%
class Bandit():
    def __init__(self, probability):
        # Qk(a) stores the mean of rewards
        self.q = 0
        #k means how many times action a (so the bandit) was chosen in the past
        self.k = 0
        # probability distribution
        self.probability = probability

    def get_reward(self):
        # rewards can be +1 (win) or 0 (Lose)
        if random() < self.probability:
            return 1
        else:
            return 0    

class NArmedBandit():
    def __init__(self):
        self.bandits = []
        self.bandits.append(Bandit(0.5))
        self.bandits.append(Bandit(0.6))
        self.bandits.append(Bandit(0.4))

    def run(self):
        for i in range(EPISODES):
            bandit = self.bandits[self.select_bandit()]
            reward = bandit.get_reward()
            self.update(bandit, reward)
            print(f'Iteration {i}, bandit {bandit.probability} with Q value {bandit.q}')        

    def select_bandit(self):
        # this is the epsilon-greedy strategy
        # with epsilon probability the agent explore otherwise it exploits
        if random() < EPSILON:
            bandit_index = randint(0, BANDITS - 1)
        else:
            bandit_index = self.get_bandit_max_q()
        return bandit_index
    
    def update (self, bandit, reward):
        bandit.k = bandit.k + 1
        bandit.q = bandit.q + (1 / (1 + bandit.k))* (reward - bandit.q)    

    def get_bandit_max_q(self):
        # we find the bandit with max Q(a) value for the greedy exploitation
        # we need the index of the bandit with max Q(a)
        max_q_bandit_index = 0
        max_q = self.bandits[max_q_bandit_index].q
        for i in range (1, BANDITS):
            if self.bandits[i].q> max_q:
                max_q = self.bandits[i].q
                max_q_bandit_index = i
        return max_q_bandit_index        

    # show statistics: how many times the given bandit was chosen
    def show_statistics(self):
        for i in range (BANDITS):
            print(f'Bandit {i} with k: {self.bandits[i].k}')

# %%
a=NArmedBandit()
a.run()
a.show_statistics()
# Out:
# Iteration 0, bandit 0.5 with Q value 0.0
# Iteration 1, bandit 0.5 with Q value 0.0
# Iteration 2, bandit 0.5 with Q value 0.0
# Iteration 3, bandit 0.5 with Q value 0.2
# Iteration 4, bandit 0.5 with Q value 0.33333333333333337
# Iteration 5, bandit 0.5 with Q value 0.28571428571428575
# Iteration 6, bandit 0.5 with Q value 0.375
# Iteration 7, bandit 0.6 with Q value 0.5
# Iteration 8, bandit 0.6 with Q value 0.33333333333333337
# Iteration 9, bandit 0.5 with Q value 0.4444444444444444
# Iteration 10, bandit 0.4 with Q value 0.0
# Iteration 11, bandit 0.5 with Q value 0.5
# Iteration 12, bandit 0.5 with Q value 0.5454545454545454
# Iteration 13, bandit 0.5 with Q value 0.49999999999999994
# Iteration 14, bandit 0.5 with Q value 0.4615384615384615
# Iteration 15, bandit 0.5 with Q value 0.5
# Iteration 16, bandit 0.5 with Q value 0.4666666666666667
# Iteration 17, bandit 0.5 with Q value 0.5
# Iteration 18, bandit 0.5 with Q value 0.5294117647058824
# Iteration 19, bandit 0.5 with Q value 0.5555555555555556
# Iteration 20, bandit 0.5 with Q value 0.5263157894736843
# Iteration 21, bandit 0.5 with Q value 0.55
# Iteration 22, bandit 0.5 with Q value 0.5238095238095238
# Iteration 23, bandit 0.5 with Q value 0.5
# Iteration 24, bandit 0.5 with Q value 0.5217391304347826
# Iteration 25, bandit 0.5 with Q value 0.5416666666666666
# Iteration 26, bandit 0.5 with Q value 0.5599999999999999
# Iteration 27, bandit 0.5 with Q value 0.5384615384615384
# Iteration 28, bandit 0.5 with Q value 0.5555555555555556
# Iteration 29, bandit 0.5 with Q value 0.5357142857142857
# Iteration 30, bandit 0.5 with Q value 0.5172413793103449
# Iteration 31, bandit 0.5 with Q value 0.5333333333333333
# Iteration 32, bandit 0.5 with Q value 0.5483870967741935
# Iteration 33, bandit 0.5 with Q value 0.5625
# Iteration 34, bandit 0.5 with Q value 0.5454545454545454
# Iteration 35, bandit 0.5 with Q value 0.5588235294117647
# Iteration 36, bandit 0.5 with Q value 0.5714285714285714
# Iteration 37, bandit 0.5 with Q value 0.5555555555555556
# Iteration 38, bandit 0.5 with Q value 0.5405405405405406
# Iteration 39, bandit 0.6 with Q value 0.25
# Iteration 40, bandit 0.6 with Q value 0.4
# Iteration 41, bandit 0.5 with Q value 0.5263157894736843
# Iteration 42, bandit 0.5 with Q value 0.5128205128205129
# Iteration 43, bandit 0.5 with Q value 0.525
# Iteration 44, bandit 0.5 with Q value 0.5121951219512195
# Iteration 45, bandit 0.5 with Q value 0.5238095238095238
# Iteration 46, bandit 0.5 with Q value 0.5348837209302326
# Iteration 47, bandit 0.5 with Q value 0.5227272727272728
# Iteration 48, bandit 0.5 with Q value 0.5111111111111112
# Iteration 49, bandit 0.5 with Q value 0.5000000000000001
# Iteration 50, bandit 0.5 with Q value 0.48936170212765967
# Iteration 51, bandit 0.5 with Q value 0.47916666666666674
# Iteration 52, bandit 0.5 with Q value 0.4693877551020409
# Iteration 53, bandit 0.5 with Q value 0.4800000000000001
# Iteration 54, bandit 0.5 with Q value 0.49019607843137264
# Iteration 55, bandit 0.5 with Q value 0.48076923076923084
# Iteration 56, bandit 0.5 with Q value 0.4905660377358491
# Iteration 57, bandit 0.5 with Q value 0.4814814814814815
# Iteration 58, bandit 0.5 with Q value 0.4727272727272728
# Iteration 59, bandit 0.5 with Q value 0.4821428571428572
# Iteration 60, bandit 0.5 with Q value 0.4736842105263159
# Iteration 61, bandit 0.5 with Q value 0.48275862068965525
# Iteration 62, bandit 0.5 with Q value 0.47457627118644075
# Iteration 63, bandit 0.5 with Q value 0.4833333333333334
# Iteration 64, bandit 0.5 with Q value 0.47540983606557385
# Iteration 65, bandit 0.5 with Q value 0.46774193548387105
# Iteration 66, bandit 0.5 with Q value 0.4603174603174604
# Iteration 67, bandit 0.5 with Q value 0.4687500000000001
# Iteration 68, bandit 0.5 with Q value 0.4615384615384617
# Iteration 69, bandit 0.5 with Q value 0.4545454545454547
# Iteration 70, bandit 0.5 with Q value 0.4626865671641793
# Iteration 71, bandit 0.4 with Q value 0.0
# Iteration 72, bandit 0.5 with Q value 0.4705882352941178
# Iteration 73, bandit 0.5 with Q value 0.46376811594202916
# Iteration 74, bandit 0.5 with Q value 0.4571428571428573
# Iteration 128, bandit 0.6 with Q value 0.6071428571428571
# Iteration 129, bandit 0.6 with Q value 0.6140350877192982
# Iteration 130, bandit 0.4 with Q value 0.2
# Iteration 131, bandit 0.4 with Q value 0.33333333333333337
# Iteration 132, bandit 0.6 with Q value 0.6034482758620688
# Iteration 133, bandit 0.6 with Q value 0.6101694915254237
# Iteration 134, bandit 0.6 with Q value 0.6
# Iteration 135, bandit 0.6 with Q value 0.6065573770491803
# Iteration 136, bandit 0.6 with Q value 0.5967741935483871
# Iteration 137, bandit 0.6 with Q value 0.6031746031746033
# Iteration 138, bandit 0.6 with Q value 0.5937500000000001
# Iteration 139, bandit 0.6 with Q value 0.5846153846153848
# Iteration 140, bandit 0.6 with Q value 0.5757575757575759
# Iteration 141, bandit 0.4 with Q value 0.28571428571428575
# Iteration 142, bandit 0.6 with Q value 0.5671641791044778
# Iteration 143, bandit 0.6 with Q value 0.5588235294117649
# Iteration 144, bandit 0.6 with Q value 0.5507246376811596
# Iteration 145, bandit 0.6 with Q value 0.5571428571428574
# Iteration 146, bandit 0.6 with Q value 0.5492957746478876
# Iteration 147, bandit 0.6 with Q value 0.5555555555555558
# Iteration 148, bandit 0.6 with Q value 0.5616438356164386
# Iteration 149, bandit 0.6 with Q value 0.5540540540540543
# Iteration 150, bandit 0.6 with Q value 0.5600000000000003
# Iteration 151, bandit 0.6 with Q value 0.5526315789473687
# Iteration 152, bandit 0.6 with Q value 0.5454545454545457
# Iteration 153, bandit 0.6 with Q value 0.5384615384615388
# Iteration 154, bandit 0.6 with Q value 0.5316455696202534
# Iteration 155, bandit 0.6 with Q value 0.5250000000000002
# Iteration 156, bandit 0.6 with Q value 0.5308641975308644
# Iteration 157, bandit 0.6 with Q value 0.5243902439024393
# Iteration 158, bandit 0.6 with Q value 0.5180722891566267
# Iteration 159, bandit 0.6 with Q value 0.5119047619047621
# Iteration 160, bandit 0.6 with Q value 0.5176470588235296
# Iteration 161, bandit 0.6 with Q value 0.5116279069767443
# Iteration 162, bandit 0.6 with Q value 0.517241379310345
# Iteration 163, bandit 0.6 with Q value 0.5113636363636365
# Iteration 164, bandit 0.4 with Q value 0.25000000000000006
# Iteration 165, bandit 0.5 with Q value 0.43835616438356184
# Iteration 166, bandit 0.6 with Q value 0.5168539325842698
# Iteration 167, bandit 0.6 with Q value 0.5222222222222224
# Iteration 168, bandit 0.6 with Q value 0.5274725274725276
# Iteration 169, bandit 0.5 with Q value 0.4324324324324326
# Iteration 170, bandit 0.6 with Q value 0.5326086956521741
# Iteration 171, bandit 0.6 with Q value 0.5268817204301077
# Iteration 172, bandit 0.6 with Q value 0.521276595744681
# Iteration 173, bandit 0.6 with Q value 0.5157894736842107
# Iteration 174, bandit 0.6 with Q value 0.5208333333333335
# Iteration 175, bandit 0.6 with Q value 0.5154639175257734
# Iteration 176, bandit 0.6 with Q value 0.5204081632653063
# Iteration 177, bandit 0.6 with Q value 0.5151515151515152
# Iteration 178, bandit 0.6 with Q value 0.5200000000000001
# Iteration 179, bandit 0.6 with Q value 0.5247524752475249
# Iteration 651, bandit 0.6 with Q value 0.6055045871559631
# Iteration 652, bandit 0.6 with Q value 0.6043956043956042
# Iteration 653, bandit 0.6 with Q value 0.6032906764168189
# Iteration 654, bandit 0.6 with Q value 0.6021897810218977
# Iteration 655, bandit 0.6 with Q value 0.6010928961748633
# Iteration 656, bandit 0.6 with Q value 0.5999999999999999
# Iteration 657, bandit 0.6 with Q value 0.6007259528130671
# Iteration 658, bandit 0.6 with Q value 0.6014492753623187
# Iteration 659, bandit 0.6 with Q value 0.6021699819168173
# Iteration 660, bandit 0.6 with Q value 0.6028880866425992
# Iteration 661, bandit 0.6 with Q value 0.6018018018018018
# Iteration 662, bandit 0.6 with Q value 0.6025179856115107
# Iteration 663, bandit 0.6 with Q value 0.6014362657091561
# Iteration 664, bandit 0.6 with Q value 0.600358422939068
# Iteration 665, bandit 0.6 with Q value 0.5992844364937387
# Iteration 666, bandit 0.6 with Q value 0.5982142857142857
# Iteration 667, bandit 0.6 with Q value 0.5971479500891266
# Iteration 668, bandit 0.6 with Q value 0.5978647686832741
# Iteration 669, bandit 0.6 with Q value 0.5985790408525755
# Iteration 670, bandit 0.6 with Q value 0.599290780141844
# Iteration 671, bandit 0.6 with Q value 0.6
# Iteration 672, bandit 0.6 with Q value 0.6007067137809187
# Iteration 673, bandit 0.6 with Q value 0.601410934744268
# Iteration 674, bandit 0.6 with Q value 0.6021126760563379
# Iteration 675, bandit 0.6 with Q value 0.602811950790861
# Iteration 676, bandit 0.6 with Q value 0.6035087719298244
# Iteration 677, bandit 0.5 with Q value 0.46067415730337086
# Iteration 678, bandit 0.6 with Q value 0.6042031523642731
# Iteration 679, bandit 0.6 with Q value 0.6048951048951048
# Iteration 680, bandit 0.6 with Q value 0.6055846422338568
# Iteration 681, bandit 0.6 with Q value 0.6045296167247386
# Iteration 682, bandit 0.6 with Q value 0.6052173913043477
# Iteration 683, bandit 0.6 with Q value 0.6059027777777777
# Iteration 684, bandit 0.6 with Q value 0.6048526863084921
# Iteration 685, bandit 0.6 with Q value 0.6055363321799306
# Iteration 686, bandit 0.6 with Q value 0.6062176165803107
# Iteration 687, bandit 0.6 with Q value 0.6068965517241377
# Iteration 688, bandit 0.6 with Q value 0.605851979345955
# Iteration 689, bandit 0.6 with Q value 0.6065292096219929
# Iteration 690, bandit 0.6 with Q value 0.6054888507718694
# Iteration 691, bandit 0.4 with Q value 0.34782608695652173
# Iteration 692, bandit 0.6 with Q value 0.6061643835616436
# Iteration 693, bandit 0.6 with Q value 0.6051282051282049
# Iteration 694, bandit 0.6 with Q value 0.6058020477815697
# Iteration 695, bandit 0.6 with Q value 0.6047700170357748
# Iteration 696, bandit 0.6 with Q value 0.6037414965986392
# Iteration 697, bandit 0.6 with Q value 0.6044142614601016
# Iteration 698, bandit 0.6 with Q value 0.6033898305084743
# Iteration 699, bandit 0.6 with Q value 0.6040609137055835
# Iteration 700, bandit 0.6 with Q value 0.6030405405405402
# Iteration 701, bandit 0.6 with Q value 0.6037099494097805
# Iteration 702, bandit 0.6 with Q value 0.6043771043771041
# Iteration 808, bandit 0.6 with Q value 0.5988372093023251
# Iteration 809, bandit 0.6 with Q value 0.5994194484760518
# Iteration 810, bandit 0.5 with Q value 0.4747474747474748
# Iteration 811, bandit 0.6 with Q value 0.5999999999999995
# Iteration 812, bandit 0.6 with Q value 0.6005788712011573
# Iteration 813, bandit 0.6 with Q value 0.5997109826589591
# Iteration 814, bandit 0.6 with Q value 0.6002886002885998
# Iteration 815, bandit 0.6 with Q value 0.6008645533141205
# Iteration 816, bandit 0.6 with Q value 0.6014388489208627
# Iteration 817, bandit 0.6 with Q value 0.602011494252873
# Iteration 818, bandit 0.6 with Q value 0.6011477761836437
# Iteration 819, bandit 0.6 with Q value 0.6002865329512889
# Iteration 820, bandit 0.6 with Q value 0.5994277539341911
# Iteration 821, bandit 0.6 with Q value 0.5999999999999994
# Iteration 822, bandit 0.6 with Q value 0.5991440798858767
# Iteration 823, bandit 0.6 with Q value 0.5997150997150991
# Iteration 824, bandit 0.6 with Q value 0.6002844950213365
# Iteration 825, bandit 0.6 with Q value 0.5994318181818176
# Iteration 826, bandit 0.6 with Q value 0.5999999999999994
# Iteration 827, bandit 0.6 with Q value 0.5991501416430589
# Iteration 828, bandit 0.6 with Q value 0.5997171145685991
# Iteration 829, bandit 0.6 with Q value 0.6002824858757057
# Iteration 830, bandit 0.6 with Q value 0.5994358251057822
# Iteration 831, bandit 0.6 with Q value 0.5999999999999994
# Iteration 832, bandit 0.6 with Q value 0.5991561181434594
# Iteration 833, bandit 0.6 with Q value 0.5997191011235949
# Iteration 834, bandit 0.6 with Q value 0.5988779803646558
# Iteration 835, bandit 0.6 with Q value 0.5980392156862739
# Iteration 836, bandit 0.6 with Q value 0.5972027972027967
# ...
# Iteration 9730, bandit 0.6 with Q value 0.6020577497510795
# Iteration 9731, bandit 0.6 with Q value 0.6021017699115053
# Iteration 9732, bandit 0.6 with Q value 0.6021457803340348
# Iteration 9733, bandit 0.6 with Q value 0.6021897810218987
# Iteration 9734, bandit 0.6 with Q value 0.6022337719783266
# Iteration 9735, bandit 0.6 with Q value 0.6022777532065466
# Iteration 9736, bandit 0.6 with Q value 0.6023217247097853
# Iteration 9737, bandit 0.6 with Q value 0.6023656864912678
# Iteration 9738, bandit 0.6 with Q value 0.6024096385542178
# Iteration 9739, bandit 0.6 with Q value 0.602343059239612
# Iteration 9740, bandit 0.6 with Q value 0.6022764946402928
# Iteration 9741, bandit 0.6 with Q value 0.6023204419889513
# Iteration 9742, bandit 0.6 with Q value 0.6023643796265616
# Iteration 9743, bandit 0.6 with Q value 0.6024083075563422
# Iteration 9744, bandit 0.6 with Q value 0.60245222578151
# Iteration 9745, bandit 0.6 with Q value 0.6024961343052806
# Iteration 9746, bandit 0.6 with Q value 0.602429596907787
# Iteration 9747, bandit 0.6 with Q value 0.6023630742049482
# Iteration 9748, bandit 0.6 with Q value 0.6024069780280458
# Iteration 9749, bandit 0.6 with Q value 0.6024508721572103
# Iteration 9750, bandit 0.6 with Q value 0.6023843691356674
# Iteration 9751, bandit 0.6 with Q value 0.6024282560706414
# Iteration 9752, bandit 0.6 with Q value 0.6023617702240384
# Iteration 9753, bandit 0.6 with Q value 0.6022952990509834
# Iteration 9754, bandit 0.6 with Q value 0.6022288425466195
# Iteration 9755, bandit 0.6 with Q value 0.6022727272727286
# Iteration 9756, bandit 0.6 with Q value 0.602206287920575
# Iteration 9757, bandit 0.6 with Q value 0.6022501654533435
# Iteration 9758, bandit 0.6 with Q value 0.602183743244735
# Iteration 9759, bandit 0.6 with Q value 0.6021173356859298
# Iteration 9760, bandit 0.6 with Q value 0.602050942772082
# Iteration 9761, bandit 0.6 with Q value 0.6020948180815889
# Iteration 9762, bandit 0.6 with Q value 0.6020284422886133
# Iteration 9763, bandit 0.6 with Q value 0.601962081128749
# Iteration 9764, bandit 0.6 with Q value 0.6020059517248993
# Iteration 9765, bandit 0.6 with Q value 0.6020498126515331
# Iteration 9766, bandit 0.6 with Q value 0.602093663911847
# Iteration 9767, bandit 0.6 with Q value 0.6021375055090361
# Iteration 9768, bandit 0.6 with Q value 0.6021813374462941
# Iteration 9769, bandit 0.6 with Q value 0.6021150033046939
# Iteration 9770, bandit 0.6 with Q value 0.6020486837757475
# Iteration 9771, bandit 0.6 with Q value 0.6020925110132171
# Iteration 9772, bandit 0.6 with Q value 0.6021363285981733
# Iteration 9773, bandit 0.6 with Q value 0.6021801365338044
# Iteration 9774, bandit 0.6 with Q value 0.6022239348232976
# Iteration 9775, bandit 0.4 with Q value 0.36950146627565983
# Iteration 9776, bandit 0.6 with Q value 0.6022677234698384
# Iteration 9777, bandit 0.6 with Q value 0.6023115024766111
# Iteration 9778, bandit 0.6 with Q value 0.6023552718467986
# Iteration 9779, bandit 0.6 with Q value 0.6023990315835823
# Iteration 9780, bandit 0.6 with Q value 0.6024427816901422
# Iteration 9781, bandit 0.6 with Q value 0.602486522169657
# Iteration 9782, bandit 0.6 with Q value 0.6025302530253039
# Iteration 9783, bandit 0.6 with Q value 0.6025739742602588
# Iteration 9784, bandit 0.4 with Q value 0.3684210526315789
# Iteration 9785, bandit 0.6 with Q value 0.6026176858776962
# Iteration 9786, bandit 0.4 with Q value 0.37026239067055394
# Iteration 9787, bandit 0.6 with Q value 0.6026613878807889
# Iteration 9788, bandit 0.6 with Q value 0.6027050802727087
# Iteration 9789, bandit 0.6 with Q value 0.602748763056626
# Iteration 9790, bandit 0.5 with Q value 0.4831460674157303
# Iteration 9791, bandit 0.6 with Q value 0.6027924362357094
# Iteration 9792, bandit 0.6 with Q value 0.6027261734637807
# Iteration 9793, bandit 0.6 with Q value 0.6027698395251717
# Iteration 9794, bandit 0.6 with Q value 0.602703593801518
# Iteration 9795, bandit 0.6 with Q value 0.602747252747254
# Iteration 9796, bandit 0.6 with Q value 0.6027909020986718
# Iteration 9797, bandit 0.6 with Q value 0.6028345418589335
# Iteration 9798, bandit 0.6 with Q value 0.6028781720311999
# Iteration 9799, bandit 0.6 with Q value 0.6028119507908625
# Iteration 9800, bandit 0.6 with Q value 0.6028555738605175
# Iteration 9801, bandit 0.6 with Q value 0.6028991873490019
# Iteration 9802, bandit 0.6 with Q value 0.602832985615462
# Iteration 9803, bandit 0.6 with Q value 0.6027667984189736
# Iteration 9804, bandit 0.6 with Q value 0.6028104072894952
# Iteration 9805, bandit 0.6 with Q value 0.6028540065861704
# Iteration 9806, bandit 0.6 with Q value 0.6028975963121515
# Iteration 9807, bandit 0.6 with Q value 0.6029411764705895
# Iteration 9808, bandit 0.6 with Q value 0.6029847470646342
# Iteration 9809, bandit 0.6 with Q value 0.6029185867895558
# Iteration 9810, bandit 0.6 with Q value 0.6029621503017017
# Iteration 9811, bandit 0.6 with Q value 0.603005704256254
# Iteration 9812, bandit 0.6 with Q value 0.6030492486563576
# Iteration 9813, bandit 0.6 with Q value 0.6030927835051559
# Iteration 9814, bandit 0.6 with Q value 0.6030266476587358
# Iteration 9815, bandit 0.6 with Q value 0.6029605263157908
# Iteration 9816, bandit 0.6 with Q value 0.6030040565727455
# Iteration 9817, bandit 0.6 with Q value 0.6029379522034654
# Iteration 9818, bandit 0.6 with Q value 0.6028718623259904
# Iteration 9819, bandit 0.6 with Q value 0.6028057869355558
# Iteration 9820, bandit 0.6 with Q value 0.6028493150684944
# Iteration 9821, bandit 0.6 with Q value 0.6027832566294117
# Iteration 9822, bandit 0.6 with Q value 0.6028267776925618
# Iteration 9823, bandit 0.6 with Q value 0.6028702892199838
# Iteration 9824, bandit 0.6 with Q value 0.602804250191698
# Iteration 9825, bandit 0.6 with Q value 0.6028477546549849
# Iteration 9826, bandit 0.6 with Q value 0.6028912495893124
# Iteration 9827, bandit 0.6 with Q value 0.6029347349978111
# Iteration 9828, bandit 0.6 with Q value 0.6029782108836101
# Iteration 9829, bandit 0.6 with Q value 0.603021677249837
# Iteration 9830, bandit 0.6 with Q value 0.6029556650246318
# Iteration 9831, bandit 0.6 with Q value 0.6029991243432588
# Iteration 9832, bandit 0.6 with Q value 0.6029331290357899
# Iteration 9833, bandit 0.6 with Q value 0.6029765813088216
# Iteration 9834, bandit 0.6 with Q value 0.6029106029106042
# Iteration 9835, bandit 0.6 with Q value 0.602954048140045
# Iteration 9836, bandit 0.6 with Q value 0.6029974838639112
# Iteration 9837, bandit 0.6 with Q value 0.6029315248304542
# Iteration 9838, bandit 0.6 with Q value 0.6029749535163527
# Iteration 9839, bandit 0.6 with Q value 0.6029090113735797
# Iteration 9840, bandit 0.6 with Q value 0.6029524330235114
# Iteration 9841, bandit 0.6 with Q value 0.6029958451782212
# Iteration 9842, bandit 0.6 with Q value 0.6030392478408234
# Iteration 9843, bandit 0.6 with Q value 0.6030826410144307
# Iteration 9844, bandit 0.6 with Q value 0.6031260247021545
# Iteration 9845, bandit 0.6 with Q value 0.6031693989071051
# Iteration 9846, bandit 0.5 with Q value 0.4817927170868347
# Iteration 9847, bandit 0.6 with Q value 0.6032127636323912
# Iteration 9848, bandit 0.6 with Q value 0.6032561188811202
# Iteration 9849, bandit 0.6 with Q value 0.6032994646563982
# Iteration 9850, bandit 0.6 with Q value 0.6033428009613298
# Iteration 9851, bandit 0.6 with Q value 0.6033861277990183
# Iteration 9852, bandit 0.6 with Q value 0.6033202271734396
# Iteration 9853, bandit 0.6 with Q value 0.6032543409413578
# Iteration 9854, bandit 0.6 with Q value 0.6032976632452515
# Iteration 9855, bandit 0.6 with Q value 0.6033409760890941
# Iteration 9856, bandit 0.6 with Q value 0.603275109170307
# Iteration 9857, bandit 0.6 with Q value 0.6033184150201957
# Iteration 9858, bandit 0.6 with Q value 0.6032525649421537
# Iteration 9859, bandit 0.6 with Q value 0.6032958638000668
# Iteration 9860, bandit 0.6 with Q value 0.6032300305543444
# Iteration 9861, bandit 0.6 with Q value 0.6031642116748513
# Iteration 9862, bandit 0.6 with Q value 0.6032075060004378
# Iteration 9863, bandit 0.6 with Q value 0.60314170393804
# Iteration 9864, bandit 0.6 with Q value 0.6031849912739979
# Iteration 9865, bandit 0.5 with Q value 0.4832402234636871
# Iteration 9866, bandit 0.6 with Q value 0.6032282691678497
# Iteration 9867, bandit 0.6 with Q value 0.6031624863685947
# Iteration 9868, bandit 0.6 with Q value 0.603205757278379
# Iteration 9869, bandit 0.6 with Q value 0.6032490187527272
# Iteration 9870, bandit 0.6 with Q value 0.6032922707947251
# Iteration 9871, bandit 0.6 with Q value 0.6032265097013313
# Iteration 9872, bandit 0.6 with Q value 0.6031607629427808
# Iteration 9873, bandit 0.6 with Q value 0.6032040104620765
# Iteration 9874, bandit 0.6 with Q value 0.6032472485561745
# Iteration 9875, bandit 0.6 with Q value 0.6032904772281558
# Iteration 9876, bandit 0.6 with Q value 0.6033336964810997
# Iteration 9877, bandit 0.6 with Q value 0.6033769063180843
# Iteration 9878, bandit 0.6 with Q value 0.6034201067421864
# Iteration 9879, bandit 0.6 with Q value 0.6034632977564816
# Iteration 9880, bandit 0.6 with Q value 0.6035064793640438
# Iteration 9881, bandit 0.6 with Q value 0.6035496515679458
# Iteration 9882, bandit 0.6 with Q value 0.603592814371259
# Iteration 9883, bandit 0.6 with Q value 0.6035271064663633
# Iteration 9884, bandit 0.5 with Q value 0.4846796657381615
# Iteration 9885, bandit 0.6 with Q value 0.6035702623272029
# Iteration 9886, bandit 0.5 with Q value 0.48611111111111105
# Iteration 9887, bandit 0.6 with Q value 0.6036134087940807
# Iteration 9888, bandit 0.6 with Q value 0.6035477201001211
# Iteration 9889, bandit 0.6 with Q value 0.6034820457018513
# Iteration 9890, bandit 0.6 with Q value 0.6034163855946049
# Iteration 9891, bandit 0.6 with Q value 0.6033507397737177
# Iteration 9892, bandit 0.5 with Q value 0.484764542936288
# Iteration 9893, bandit 0.6 with Q value 0.6032851082345276
# Iteration 9894, bandit 0.6 with Q value 0.6033282575592791
# Iteration 9895, bandit 0.6 with Q value 0.6032626427406212
# Iteration 9896, bandit 0.6 with Q value 0.6033057851239683
# Iteration 9897, bandit 0.6 with Q value 0.603240187017507
# Iteration 9898, bandit 0.6 with Q value 0.6031746031746045
# Iteration 9899, bandit 0.6 with Q value 0.603109033590609
# Iteration 9900, bandit 0.6 with Q value 0.6031521739130448
# Iteration 9901, bandit 0.6 with Q value 0.6031953048581689
# Iteration 9902, bandit 0.6 with Q value 0.6032384264290385
# Iteration 9903, bandit 0.6 with Q value 0.6032815386287094
# Iteration 9904, bandit 0.6 with Q value 0.6032159930465029
# Iteration 9905, bandit 0.6 with Q value 0.6032590983161339
# Iteration 9906, bandit 0.6 with Q value 0.6033021942211615
# Iteration 9907, bandit 0.6 with Q value 0.603345280764637
# Iteration 9908, bandit 0.6 with Q value 0.6032797567332768
# Iteration 9909, bandit 0.6 with Q value 0.6032142469323502
# Iteration 9910, bandit 0.6 with Q value 0.6032573289902293
# Iteration 9911, bandit 0.6 with Q value 0.6033004016936285
# Iteration 9912, bandit 0.6 with Q value 0.603343465045594
# Iteration 9913, bandit 0.6 with Q value 0.603386519049171
# Iteration 9914, bandit 0.6 with Q value 0.6034295637074031
# Iteration 9915, bandit 0.6 with Q value 0.6034725990233328
# Iteration 9916, bandit 0.6 with Q value 0.6035156250000013
# Iteration 9917, bandit 0.6 with Q value 0.6035586416404484
# Iteration 9918, bandit 0.6 with Q value 0.6036016489477124
# Iteration 9919, bandit 0.6 with Q value 0.6036446469248306
# Iteration 9920, bandit 0.6 with Q value 0.6035791757049905
# Iteration 9921, bandit 0.6 with Q value 0.6036221667931908
# Iteration 9922, bandit 0.4 with Q value 0.37209302325581395
# Iteration 9923, bandit 0.6 with Q value 0.603665148557798
# Iteration 9924, bandit 0.5 with Q value 0.4861878453038673
# Iteration 9925, bandit 0.6 with Q value 0.6037081210018446
# Iteration 9926, bandit 0.6 with Q value 0.6036426712922823
# Iteration 9927, bandit 0.6 with Q value 0.6036856368563699
# Iteration 9928, bandit 0.6 with Q value 0.6037285931064397
# Iteration 9929, bandit 0.6 with Q value 0.6037715400455199
# Iteration 9930, bandit 0.6 with Q value 0.6038144776766377
# Iteration 9931, bandit 0.6 with Q value 0.6038574060028186
# Iteration 9932, bandit 0.6 with Q value 0.6039003250270869
# Iteration 9933, bandit 0.5 with Q value 0.4876033057851239
# Iteration 9934, bandit 0.6 with Q value 0.6039432347524658
# Iteration 9935, bandit 0.6 with Q value 0.6038778162911624
# Iteration 9936, bandit 0.6 with Q value 0.6038124120004345
# Iteration 9937, bandit 0.6 with Q value 0.6037470218756781
# Iteration 9938, bandit 0.6 with Q value 0.6036816459122915
# Iteration 9939, bandit 0.6 with Q value 0.6037245560848865
# Iteration 9940, bandit 0.6 with Q value 0.6036591967088895
# Iteration 9941, bandit 0.6 with Q value 0.603702100021651
# Iteration 9942, bandit 0.6 with Q value 0.6037449940469761
# Iteration 9943, bandit 0.6 with Q value 0.6037878787878801
# Iteration 9944, bandit 0.6 with Q value 0.6037225408505587
# Iteration 9945, bandit 0.6 with Q value 0.6037654187405337
# Iteration 9946, bandit 0.6 with Q value 0.6038082873525925
# Iteration 9947, bandit 0.6 with Q value 0.603851146689746
# Iteration 9948, bandit 0.4 with Q value 0.3710144927536232
# Iteration 9949, bandit 0.6 with Q value 0.6038939967550041
# Iteration 9950, bandit 0.6 with Q value 0.603936837551375
# Iteration 9951, bandit 0.6 with Q value 0.6039796690818657
# Iteration 9952, bandit 0.6 with Q value 0.603914359861593
# Iteration 9953, bandit 0.6 with Q value 0.6039571845604944
# Iteration 9954, bandit 0.6 with Q value 0.6040000000000014
# Iteration 9955, bandit 0.6 with Q value 0.6040428061831168
# Iteration 9956, bandit 0.6 with Q value 0.6039775183744069
# Iteration 9957, bandit 0.6 with Q value 0.6039122446774033
# Iteration 9958, bandit 0.6 with Q value 0.6039550464663943
# Iteration 9959, bandit 0.6 with Q value 0.6038897893030808
# Iteration 9960, bandit 0.5 with Q value 0.4862637362637362
# Iteration 9961, bandit 0.6 with Q value 0.6038245462402779
# Iteration 9962, bandit 0.6 with Q value 0.6038673436318475
# Iteration 9963, bandit 0.6 with Q value 0.6039101317779231
# Iteration 9964, bandit 0.6 with Q value 0.6039529106815004
# Iteration 9965, bandit 0.6 with Q value 0.6038876889848825
# Iteration 9966, bandit 0.6 with Q value 0.6039304610733196
# Iteration 9967, bandit 0.6 with Q value 0.6039732239257194
# Iteration 9968, bandit 0.6 with Q value 0.603908021159453
# Iteration 9969, bandit 0.6 with Q value 0.6039507772020739
# Iteration 9970, bandit 0.6 with Q value 0.603993524015112
# Iteration 9971, bandit 0.6 with Q value 0.6039283401683587
# Iteration 9972, bandit 0.6 with Q value 0.6039710801769733
# Iteration 9973, bandit 0.6 with Q value 0.6040138109624527
# Iteration 9974, bandit 0.6 with Q value 0.604056532527782
# Iteration 9975, bandit 0.5 with Q value 0.484931506849315
# Iteration 9976, bandit 0.6 with Q value 0.6040992448759451
# Iteration 9977, bandit 0.6 with Q value 0.6041419480099246
# Iteration 9978, bandit 0.6 with Q value 0.6040767903364982
# Iteration 9979, bandit 0.6 with Q value 0.6041194866817655
# Iteration 9980, bandit 0.6 with Q value 0.604162173819281
# Iteration 9981, bandit 0.6 with Q value 0.6042048517520228
# Iteration 9982, bandit 0.6 with Q value 0.604247520482968
# Iteration 9983, bandit 0.6 with Q value 0.6041823865473764
# Iteration 9984, bandit 0.6 with Q value 0.6041172666522969
# Iteration 9985, bandit 0.6 with Q value 0.6040521607931901
# Iteration 9986, bandit 0.5 with Q value 0.4863387978142076
# Iteration 9987, bandit 0.5 with Q value 0.48773841961852854
# Iteration 9988, bandit 0.6 with Q value 0.6040948275862081
# Iteration 9989, bandit 0.4 with Q value 0.37283236994219654
# Iteration 9990, bandit 0.6 with Q value 0.6041374851847874
# Iteration 9991, bandit 0.6 with Q value 0.6040723981900465
# Iteration 9992, bandit 0.6 with Q value 0.6040073252181419
# Iteration 9993, bandit 0.6 with Q value 0.6040499784575626
# Iteration 9994, bandit 0.6 with Q value 0.604092622509425
# Iteration 9995, bandit 0.6 with Q value 0.6041352573766973
# Iteration 9996, bandit 0.6 with Q value 0.6040702056638323
# Iteration 9997, bandit 0.6 with Q value 0.6040051679586574
# Iteration 9998, bandit 0.6 with Q value 0.6040477984713113
# Iteration 9999, bandit 0.6 with Q value 0.6040904198062444
# Bandit 0 with k: 366
# Bandit 1 with k: 9289
# Bandit 2 with k: 345

# %%
import random
from keras.models import Sequential
from keras.layers import Dense
import numpy as np

BLANK = ' '
AI_PLAYER = 'X'
HUMAN_PLAYER = 'O'
TRAINING_EPOCHS = 20000
TRAINING_EPSILON = 0.4
REWARD_WIN = 10
REWARD_LOSE = -10
REWARD_TIE = 0


class Player:

    @staticmethod
    def show_board(board):
        print('|'.join(board[0:3]))
        print('|'.join(board[3:6]))
        print('|'.join(board[6:9]))


class HumanPlayer(Player):

    def reward(self, value, board):
        pass

    def make_move(self, board):

        while True:
            try:
                self.show_board(board)
                move = input('Your next move (cell index 1-9):')
                move = int(move)
                if not (move - 1 in range(9)):
                    raise ValueError
            except ValueError:
                print('Invalid move; try again:\n')
            else:
                return move - 1


class AIPlayer(Player):

    def __init__(self, epsilon=0.4, alpha=0.3, gamma=0.9):
        # this is the epsilon parameter of the model: the probability of exploration
        self.EPSILON = epsilon
        # learning rate
        self.ALPHA = alpha
        # discount parameter for future reward (rewards now are better than rewards in the future)
        self.GAMMA = gamma

        # the Q(s,a) function is a neural network (this is how we eliminate the huge data structure)
        # single hidden layer with 32 neurons - output is 1 which is the optimal move (so the index)
        # input neurons: 36
        self.q = Sequential()
        self.q.add(Dense(32, input_dim=36, activation='relu'))
        self.q.add(Dense(1, activation='relu'))
        self.q.compile(optimizer='adam', loss='mean_squared_error')
        # previous move during the game
        self.move = None
        # board in the previous iteration
        self.board = (' ',) * 9

    def available_moves(self, board):
        return [i for i in range(9) if board[i] == ' ']

    def encode_input(self, board, action):
        # we represent the (s,a) pair with a one-dimensional array (one-hot reresentation)
        vector_representation = []

        # one-hot encoding for the 3 states
        # [1,0,0] - it means the given cell has X ticker
        # [0,1,0] - it means the given cell has O ticker
        # [0,0,1] - it means the given cell has ' ' ticker so empty
        # every single cell on the board (9 cells) has 3 values because of this representation
        # so there are 9x3=27 values
        for cell in board:
            for ticker in ['X', 'O', ' ']:
                if cell == ticker:
                    vector_representation.append(1)
                else:
                    vector_representation.append(0)

        # one-hot encoding of the action - array with size 9
        # [1,0,0,0,0,0,0,0,0] - it means putting X to the first cell
        # [0,1,0,0,0,0,0,0,0] - it means putting X to the second cell
        for move in range(9):
            if action == move:
                vector_representation.append(1)
            else:
                vector_representation.append(0)

        # all together there are 27+9=36 values (the input layer has 36 neurons)
        return np.array([vector_representation])

    # make a random move with epsilon probability (exploration) or pick the action with the
    # highest Q value (exploitation)
    def make_move(self, board):

        self.board = tuple(board)
        actions = self.available_moves(board)

        # action with epsilon probability
        if random.random() < self.EPSILON:
            # this is in index (0-8 board cell related index)
            self.move = random.choice(actions)
            return self.move

        # take the action with highest Q value
        q_values = [self.get_q(self.board, a) for a in actions]
        max_q_value = max(q_values)

        # if multiple best actions, choose one at random
        if q_values.count(max_q_value) > 1:
            best_actions = [i for i in range(len(actions)) if q_values[i] == max_q_value]
            best_move = actions[random.choice(best_actions)]
        # there is just a single best move (best action)
        else:
            best_move = actions[q_values.index(max_q_value)]

        self.move = best_move
        return self.move

    # Q(s,a) - we have the input (s,a) representation and the neural network will make
    # a prediction (returns the Q value - this value will be learned during training)
    def get_q(self, state, action):
        return self.q.predict([self.encode_input(state, action)], batch_size=1)

    # let's evaluate a given state: so update the Q(s,a) table regarding s state and a action
    def reward(self, reward, board):
        if self.move:
            prev_q = self.get_q(self.board, self.move)
            max_q_new = max([self.get_q(tuple(board), a) for a in self.available_moves(self.board)])
            # train the neural network with the new (s,a) and Q value
            self.q.fit(self.encode_input(self.board, self.move),
                       prev_q + self.ALPHA * ((reward + self.GAMMA * max_q_new) - prev_q),
                       epochs=3, verbose=0)

        self.move = None
        self.board = None


class TicTacToe:

    def __init__(self, player1, player2):
        self.player1 = player1
        self.player2 = player2
        self.first_player_turn = random.choice([True, False])
        self.board = [' '] * 9

    def play(self):

        # this is the "game loop"
        while True:
            if self.first_player_turn:
                player = self.player1
                other_player = self.player2
                player_tickers = (AI_PLAYER, HUMAN_PLAYER)
            else:
                player = self.player2
                other_player = self.player1
                player_tickers = (HUMAN_PLAYER, AI_PLAYER)

            # check the state of the game (win, lose or draw)
            game_over, winner = self.is_game_over(player_tickers)

            # game is over: handle the rewards
            if game_over:
                if winner == player_tickers[0]:
                    player.show_board(self.board[:])
                    print('\n %s won!' % player.__class__.__name__)
                    player.reward(REWARD_WIN, self.board[:])
                    other_player.reward(REWARD_LOSE, self.board[:])
                if winner == player_tickers[1]:
                    player.show_board(self.board[:])
                    print('\n %s won!' % other_player.__class__.__name__)
                    other_player.reward(REWARD_WIN, self.board[:])
                    player.reward(REWARD_LOSE, self.board[:])
                else:
                    player.show_board(self.board[:])
                    print('Tie!')
                    player.reward(REWARD_TIE, self.board[:])
                    other_player.reward(REWARD_TIE, self.board[:])
                break

            # next player's turn in the next iteration
            self.first_player_turn = not self.first_player_turn

            # actual player's best move (based on Q(s,a) table for AI player)
            move = player.make_move(self.board)
            self.board[move] = player_tickers[0]

    def is_game_over(self, player_tickers):

        # consider both players (X and O players - these are the tickers)
        for player_ticker in player_tickers:

            # check horizontal dimension (so the rows)
            for i in range(3):
                if self.board[3 * i + 0] == player_ticker and\
                        self.board[3 * i + 1] == player_ticker and\
                        self.board[3 * i + 2] == player_ticker:
                    return True, player_ticker

            # check vertical dimension (so the columns)
            for j in range(3):
                if self.board[i + 0] == player_ticker and\
                        self.board[i + 3] == player_ticker and\
                        self.board[i + 6] == player_ticker:
                    return True, player_ticker

            # check diagonal dimensions (top left to bottom right + top right to bottom left)
            if self.board[0] == player_ticker and self.board[4] == player_ticker and self.board[8] == player_ticker:
                return True, player_ticker

            if self.board[2] == player_ticker and self.board[4] == player_ticker and self.board[6] == player_ticker:
                return True, player_ticker

        # finally we can deal with the 'draw' cases
        if self.board.count(' ') == 0:
            return True, None
        else:
            return False, None


if __name__ == '__main__':

    ai_player_1 = AIPlayer()
    ai_player_2 = AIPlayer()

    print('Training')
    ai_player_1.EPSILON = TRAINING_EPSILON
    ai_player_1.EPSILON = TRAINING_EPSILON

    for i in range(TRAINING_EPOCHS):
        print("Training iteration %s" % i)
        game = TicTacToe(ai_player_1, ai_player_2)
        game.play()

    print('\nTraining is Done')

    # epsilon=0 means no exploration - it will use the Q(s,a) function to make the moves
    ai_player_1.EPSILON = 0
    human_player = HumanPlayer()
    game = TicTacToe(ai_player_1, human_player)
    game.play()
# Out:
# Training
# Training iteration 0
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 84ms/step
# O|X|X
# O|O|X
# X|O|O
#
#  AIPlayer won!
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
